# %%
si = 'welcome'
si
# Out:
# 'welcome'

# %% [markdown]
# step slicing

# %%
si ='welcome'
si[0:7:2]
si
# Out:
# 'welcome'

# %%
si[-5:-1]
si
# Out:
# 'welcome'

# %% [markdown]
# python type casting

# %%
110.65
# Out:
# 110.65

# %%
int(110.67)
# Out:
# 110

# %%
int(True) #we can convort bool ti int
# Out:
# 1

# %%
int(1+2j)# complex to integer not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10') #number string to integer possible

# %%
int('sona')# where text string to integer not possible

# %% [markdown]
# other data type to float

# %%
float(110)
# Out:
# 110.0

# %%
float(True)
# Out:
# 1.0

# %%
float(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 float(false)
#
# NameError: name 'false' is not defined

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10') #number string
# Out:
# 10.0

# %%
float('ten')#text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# other data type to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+3j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(-2)
# Out:
# True

# %% [markdown]
# other data type to complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(2,4)
# Out:
# (2+4j)

# %%
complex(1,3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 complex(1,3,5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.5)
# Out:
# (2.5+0j)

# %%
complex(2.5,6.7)
# Out:
# (2.5+6.7j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('20','40')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 complex('20','40')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# other data type to string

# %%
str(10)
# Out:
# '10'

# %%
str(10.6)
# Out:
# '10.6'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+3j)
# Out:
# '(1+3j)'
