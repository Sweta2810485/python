# %% [markdown]
# CLASS WORK

# %% [markdown]
# NUMBER SYSTEM

# %%
25
# Out:
# 25

# %%
0b(25)
# Out:
#   Cell In[2], line 1
#     0b(25)
#      ^
# SyntaxError: invalid binary literal

# %%
bin(25)# number to binary number system
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11001)# binary  number system to integer
# Out:
# 25

# %%
int()
# Out:
# 0

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0xc)
# Out:
# 12

# %%
int(0x19)
# Out:
# 25

# %% [markdown]
# BITWISE OPERATOR

# %% [markdown]
# COMPLEMENT

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
12 & 30
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
12<<2
# Out:
# 48

# %%
12>>1
# Out:
# 6

# %% [markdown]
# swap vaeiable

# %%
a = 5
b = 6

# %%
a = b
b = a
print(a)
print(b)
# Out:
# 6
# 6

# %%
a , b = 7
b = a
print(a)
print(b)
