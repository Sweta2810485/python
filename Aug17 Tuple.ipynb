# %% [markdown]
# previous day i complete the entire list

# %% [markdown]
# Tuple

# %%
t =()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10,True, 3.6, 1+2j,'sona')
t1
# Out:
# (10, True, 3.6, (1+2j), 'sona')

# %%
len(t1)
# Out:
# 5

# %%
t1[0]
# Out:
# 10

# %%
t1[0:4]
# Out:
# (10, True, 3.6, (1+2j))

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(1+2j)
# Out:
# 3

# %%
t1
# Out:
# (10, True, 3.6, (1+2j), 'sona')

# %%
t = (10,60,57)

# %%
t
# Out:
# (10, 60, 57)

# %%
t*3
# Out:
# (10, 60, 57, 10, 60, 57, 10, 60, 57)

# %%
sbi = (76508, 'sertg', 5889,'vyhuku')

# %%
sbi
# Out:
# (76508, 'sertg', 5889, 'vyhuku')

# %% [markdown]
# Tuple Slicing

# %%
t1
# Out:
# (10, True, 3.6, (1+2j), 'sona')

# %%
t1[0:2]
# Out:
# (10, True)

# %%
t1[:]
# Out:
# (10, True, 3.6, (1+2j), 'sona')

# %% [markdown]
# Remove & change items

# %%
t1.index(10)
# Out:
# 0

# %%
t1.index("sona")
# Out:
# 4

# %% [markdown]
# Sorting

# %%
t1
# Out:
# (10, True, 3.6, (1+2j), 'sona')

# %%
sorted(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sorted(t1)
#
# TypeError: '<' not supported between instances of 'complex' and 'float'

# %%
t2 = (89,9,45)

# %%
t2
# Out:
# (89, 9, 45)

# %% [markdown]
# Tuple membership

# %%
t2
# Out:
# (89, 9, 45)

# %%
9 in t2
# Out:
# True

# %% [markdown]
# loop

# %%
for i in t2:
    print(i)
# Out:
# 89
# 9
# 45

# %%
for i in enumerate(t2):
    print(i)
# Out:
# (0, 89)
# (1, 9)
# (2, 45)
