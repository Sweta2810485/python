# %% [markdown]
# VARIABLE

# %% [markdown]
# SYNTAX: variable_name = value

# %%
age = 24 #integer variable
age
# Out:
# 24

# %%
name = "sweta" #string variable
name
# Out:
# 'sweta'

# %%
price = 30.6 # float variable
price
# Out:
# 30.6

# %%
is_active = True # boolean variable
print(is_active)
# Out:
# True

# %%
x = 20 #storing a printing value
print(x)
# Out:
# 20

# %%
a =4 #using variable in expression
b = 7
add = a+b
print(add)
# Out:
# 11

# %% [markdown]
# changing the value of variable

# %%
 score = 30  #changing the value of variable
print(score)
# Out:
# 30

# %%
 score = 30  #changing the value of variable
print(score)
score = 80
print(score)
# Out:
# 30
# 80

# %%
#concatenating string
first_name = "sweta"
second_name = "prangya"
full_name = first_name + second_name
print(full_name)
# Out:
# swetaprangya

# %%
#using variables in a calculation
length = 14
width = 3
area = length * width
print(area)
# Out:
# 42

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# python variable = value \n
# value == datatype

# %%
a =7
type(a)
# Out:
# int

# %%
first_name = 'SWETA'
last_name = 'PRANGYA'
country = 'HYD'
city = 'TELENGANA'
age = 23
is_married = False
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Asabeneh', 
    'lastname':'Yetayeh', 
    'country':'Finland',
    'city':'Helsinki'
    }

# %%
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)
# Out:
# First name: SWETA
# First name length: 5
# Last name:  PRANGYA
# Last name length:  7
# Country:  HYD
# City:  TELENGANA
# Age:  23
# Married:  False
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}

# %%
irst_name, last_name, country, age, is_married = 'sweta', 'prangya', 'Helsink', 23, False

# %%
print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# SWETA prangya Helsink 23 False
# First name: SWETA
# Last name:  prangya
# Country:  Helsink
# Age:  23
# Married:  False

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sahoo\OneDrive\Desktop\Data science nareshit
