# %% [markdown]
# PYTHON DATA STRUCTURE

# %% [markdown]
# data type vs data structure,
# data type - user assign as single value.
# data structure - user assign as multiple value.
# These data structure are- list, tuple,set,dictionary,range

# %% [markdown]
# LIST- It always define as [] sqare bracket.

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(10,20,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l.append(10,20,40)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l

# %%
l.append(20)
l.append(50)
l.append(70)
l.append(80)
l

# %%
len(l)
# Out:
# 1

# %%
l.append(10) # duplicate value is allowed

# %%
l
# Out:
# [10, 10]

# %%
l1 = [10, 17.8,True, 2+7j, 'welcome']
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome']

# %%
l1.append([5,7,8])# list inside list is nested list
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
print(l)
print(l1)
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l
# Out:
# [10, 10]

# %%
l3 = l.copy()
l3
# Out:
# [10, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# [10, 10]

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 1512566769792
# 1512619105856

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# [10, 10]

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)# it not use then its go to the garbeg collector
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.count(20)
# Out:
# 0

# %%
l.count(10)
# Out:
# 2

# %%
print(l)
print(l1)
# Out:
# [10, 10]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.extend(l1)
l
# Out:
# [10, 10, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
print(l)
print(l1)
# Out:
# [10, 10, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 10, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.index(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l.index(20)
#
# ValueError: 20 is not in list

# %%
l1.index(2+7j)
# Out:
# 3

# %%
l1.index('welcome')
# Out:
# 4

# %%
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1[:]
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1[5]
# Out:
# [5, 7, 8]

# %%
l1[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 l1[7]
#
# IndexError: list index out of range

# %%
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1[:3]
# Out:
# [10, 17.8, True]

# %%
l1[3:]
# Out:
# [(2+7j), 'welcome', [5, 7, 8]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'welcome']

# %%
l1[-3]
# Out:
# (2+7j)

# %%
l1[-3:]
# Out:
# [(2+7j), 'welcome', [5, 7, 8]]

# %%
l1[::-1]
# Out:
# [[5, 7, 8], 'welcome', (2+7j), True, 17.8, 10]

# %%
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1[::-2]
# Out:
# [[5, 7, 8], (2+7j), 17.8]

# %%
l1[4]
# Out:
# 'welcome'

# %%
print(l1[4][0])#nested indexing
# Out:
# w

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
print(l1[4][6])
# Out:
# w
# e
# l
# c
# o
# m
# e

# %%
print(l1[4][7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(l1[4][7])
#
# IndexError: string index out of range

# %%
l1
# Out:
# [10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 199

# %%
print(l)
print(l1)
# Out:
# [10, 10, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]
# [199, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
print(l2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(l2)
#
# NameError: name 'l2' is not defined

# %%
print(l)
# Out:
# [10, 10, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.insert(2,25)
l
# Out:
# [10, 10, 25, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.insert(2,[1,32])
l
# Out:
# [10, 10, [1, 32], 25, 10, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l.pop()# removed last index
# Out:
# 'welcome'

# %%
l
# Out:
# [10, 10, [1, 32], 25, 10, 17.8, True, (2+7j)]

# %%
l.pop(-2)
# Out:
# True

# %%
l
# Out:
# [10, 10, [1, 32], 25, 10, 17.8, (2+7j)]

# %%
l.remove(2+7j)

# %%
l
# Out:
# [10, 10, [1, 32], 25, 10, 17.8]

# %%
print(l)
print(l1)
# Out:
# [10, 10, [1, 32], 25, 10, 17.8]
# [199, 17.8, True, (2+7j), 'welcome', [5, 7, 8]]

# %%
l1.reverse()

# %%
l1
# Out:
# [[5, 7, 8], 'welcome', (2+7j), True, 17.8, 199]

# %%
l[::-1]
# Out:
# [17.8, 10, 25, [1, 32], 10, 10]

# %%
l2 = ['s','w','e','t','a']
l2
# Out:
# ['s', 'w', 'e', 't', 'a']

# %%
l2.reverse()

# %%
l2
# Out:
# ['a', 't', 'e', 'w', 's']

# %%
l
# Out:
# [10, 10, [1, 32], 25, 10, 17.8]

# %%
l3 = [10, 10, 25, 10, 17.8]

# %%
l3
# Out:
# [10, 10, 25, 10, 17.8]

# %%
l3.sort()
l3
# Out:
# [10, 10, 10, 17.8, 25]

# %%
l3.sort(reverse=True)
l3
# Out:
# [25, 17.8, 10, 10, 10]

# %%
l3
# Out:
# [25, 17.8, 10, 10, 10]

# %%
25 in l3 # list membership
# Out:
# True

# %%
100 in l3
# Out:
# False

# %%
for i in l3:
    print(i)
# Out:
# 25
# 17.8
# 10
# 10
# 10

# %%
for i in enumerate(l3):
    print(i)
# Out:
# (0, 25)
# (1, 17.8)
# (2, 10)
# (3, 10)
# (4, 10)

# %%
l3
# Out:
# [25, 17.8, 10, 10, 10]

# %%
all(l3)
# Out:
# True

# %%
any (l3)
# Out:
# True

# %%
l3.append(0)
l3
# Out:
# [25, 17.8, 10, 10, 10, 0, 0]

# %%
all(l3)
# Out:
# False
