# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
Def = 56
Def
# Out:
# 56

# %%
i = 5 
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
i
# Out:
# 5

# %%
id(i)
# Out:
# 140723688420392

# %%
age = 24 
age
# Out:
# 24

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140723688421000

# %%
f = 110.23
f
# Out:
# 110.23

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 2418648438960

# %%
print(i)
print(f)
# Out:
# 5
# 110.23

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b
# Out:
# True

# %%
type(b1)
# Out:
# bool

# %%
p = 20
q = 20

# %%
p, q = 20, 20

# %%
print(id(p))
print(id(q))
# Out:
# 140723688420872
# 140723688420872

# %%
print(p)
print(q)
# Out:
# 20
# 20

# %%
p = p + 10
p
# Out:
# 30

# %%
print(p)
print(q)
# Out:
# 30
# 20

# %%
print(id(p))
print(id(q))
# Out:
# 140723688421192
# 140723688420872

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
c = 10 + 20j 
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 20+30J
c
# Out:
# (10+20j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0
