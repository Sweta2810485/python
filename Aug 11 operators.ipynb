# %% [markdown]
# OPERATORS

# %%
2+3
# Out:
# 5

# %%
2+3
10-4
# Out:
# 6

# %%
print(2+3)
print(2+7)
# Out:
# 5
# 9

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(a,b)
# Out:
# 10 20

# %%
c=30
print(a,b,c)
# Out:
# 10 20 30

# %%
print(a)
print(b)
print(c)
print(a,b,c)
# Out:
# 10
# 20
# 30
# 10 20 30

# %%
print(10)
print(10,20)
print('sona')
print(28,6,'sona')
# Out:
# 10
# 10 20
# sona
# 28 6 sona

# %%
print()

# %%
a=20
c=35
add=a+c
print(add)
# Out:
# 55

# %%
a=20
c=35
add=a+c
print('the addition of',a,'add',c,'is=',add)
# Out:
# the addition of 20 add 35 is= 55

# %%
name = 'Sona'
age = 23
city = 'bbsr'
print('My name is',Sona,'and i am',age,'years old')

# %% [markdown]
# Print() format method

# %%
num1=10
num2=30
num3=50
add=num1+num2+num3
print('the addition of {} and {} and {} is='{add}')
# Out:
#   Cell In[14], line 5
#     print('the addition of {} and {} and {} is='{add}')
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
print('hello')
print('baba')
# Out:
# hello
# baba

# %% [markdown]
# PRINT WITH FORMAT METHOD

# %%
num1=20
num2=30

add=num1+num2

print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %%
num1 = 20
num2 = 30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
print('hello') # 1st statement
print('good evening') # 2nd statement)
# Out:
# hello
# good evening

# %%
print('hello', end=' ') # 1st statement
print('world good day')
# Out:
# hello world good day

# %%
print('hello', end=' ### ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello ### world good day

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you
